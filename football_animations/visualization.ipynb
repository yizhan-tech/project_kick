# %% [markdown]
# # Tactical Storytelling with KICK: A Manim-Powered Soccer Visualization Toolkit

# %%
from manim.utils.ipython_magic import ManimMagic

# Clear the internal registry of rendered files to prevent unlinking errors
if "manim" in get_ipython().magics_manager.magics["cell"]:
    manim_magic = get_ipython().magics_manager.magics["cell"]["manim"].__self__
    manim_magic.rendered_files = {}
    print("Manim magic registry cleared!")
# Out:
# Manim magic registry cleared!

# %%
# %load_ext autoreload
# %autoreload 2

from manim import *
from pitch_helper import StandardPitch
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%manim -v WARNING -ql --format=gif PitchAnimation
#
# class PitchAnimation(Scene):
#     def construct(self):
#         # This scale fits a 16:9 screen nicely
#         pitch = StandardPitch(orientation="horizontal", scale=0.08)
#
#         self.play(Create(pitch))
#         self.wait()
# Out:
# Manim Community v0.19.0
